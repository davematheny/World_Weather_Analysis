# %%
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=691d166488ac52aa17c2d1c3a1a5c0cf

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palmer
# Processing Record 2 of Set 1 | aloleng
# Processing Record 3 of Set 1 | lithgow
# Processing Record 4 of Set 1 | fresnillo
# Processing Record 5 of Set 1 | krasnoselkup
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | tucurui
# Processing Record 14 of Set 1 | chara
# Processing Record 15 of Set 1 | saldanha
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | bandarbeyla
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | prieska
# Processing Record 23 of Set 1 | sabang
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | olafsvik
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | udachnyy
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | montrose
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | rio gallegos
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | chapais
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | te anau
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | north bend
# Processing Record 48 of Set 1 | notodden
# Processing Record 49 of Set 1 | catamarca
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | yar-sale
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | tautira
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | tambovka
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | esperance
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | ossora
# Processing Record 21 of Set 2 | constitucion
# Processing Record 22 of Set 2 | canela
# Processing Record 23 of Set 2 | korla
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | verkhnevilyuysk
# Processing Record 30 of Set 2 | camacha
# Processing Record 31 of Set 2 | leningradskiy
# Processing Record 32 of Set 2 | mareeba
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | portland
# Processing Record 35 of Set 2 | touros
# Processing Record 36 of Set 2 | el rosario
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | teya
# Processing Record 39 of Set 2 | natal
# Processing Record 40 of Set 2 | oktyabrskoye
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | genhe
# Processing Record 43 of Set 2 | takoradi
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | san quintin
# Processing Record 46 of Set 2 | alofi
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | macau
# Processing Record 49 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 2 | kamaishi
# Processing Record 1 of Set 3 | jacareacanga
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | yenagoa
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | chengde
# Processing Record 8 of Set 3 | harqalah
# Processing Record 9 of Set 3 | newburyport
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | vrises
# Processing Record 15 of Set 3 | khvoynaya
# Processing Record 16 of Set 3 | nanhai
# Processing Record 17 of Set 3 | lianran
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | corowa
# Processing Record 20 of Set 3 | ocos
# Processing Record 21 of Set 3 | uyuni
# Processing Record 22 of Set 3 | durusu
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | poso
# Processing Record 25 of Set 3 | hobyo
# Processing Record 26 of Set 3 | kavaratti
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | jalu
# Processing Record 29 of Set 3 | moron
# Processing Record 30 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | laredo
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | khartoum
# Processing Record 35 of Set 3 | fort nelson
# Processing Record 36 of Set 3 | mahibadhoo
# Processing Record 37 of Set 3 | high rock
# Processing Record 38 of Set 3 | gunjur
# Processing Record 39 of Set 3 | mangochi
# Processing Record 40 of Set 3 | orchard homes
# Processing Record 41 of Set 3 | tevaitoa
# Processing Record 42 of Set 3 | qaqortoq
# Processing Record 43 of Set 3 | arlit
# Processing Record 44 of Set 3 | port macquarie
# Processing Record 45 of Set 3 | tumbagaan
# Processing Record 46 of Set 3 | sturgis
# Processing Record 47 of Set 3 | aasiaat
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | ayia
# City not found. Skipping...
# Processing Record 50 of Set 3 | solnechnyy
# Processing Record 1 of Set 4 | el alto
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | xai-xai
# Processing Record 7 of Set 4 | sao filipe
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | rio grande
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | farafenni
# Processing Record 13 of Set 4 | noyabrsk
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | baruun-urt
# Processing Record 16 of Set 4 | jibuti
# Processing Record 17 of Set 4 | epe
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | bambanglipuro
# Processing Record 20 of Set 4 | labuhan
# Processing Record 21 of Set 4 | pacific grove
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | volokonovka
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | kokopo
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | kudowa-zdroj
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 4 | ostrovnoy
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | finschhafen
# Processing Record 35 of Set 4 | tabas
# Processing Record 36 of Set 4 | akdepe
# Processing Record 37 of Set 4 | lar
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 4 | tiznit
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | vallenar
# Processing Record 43 of Set 4 | ilo
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | abu samrah
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | delmas
# Processing Record 48 of Set 4 | ghanzi
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | kagoro
# Processing Record 1 of Set 5 | igarka
# Processing Record 2 of Set 5 | abha
# Processing Record 3 of Set 5 | port lincoln
# Processing Record 4 of Set 5 | sampit
# Processing Record 5 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | sistranda
# Processing Record 8 of Set 5 | kilimatinde
# Processing Record 9 of Set 5 | tura
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | komsomolskiy
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | east london
# Processing Record 14 of Set 5 | ballina
# Processing Record 15 of Set 5 | lazaro cardenas
# Processing Record 16 of Set 5 | bocanda
# Processing Record 17 of Set 5 | irbeyskoye
# Processing Record 18 of Set 5 | wajima
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | lulea
# Processing Record 21 of Set 5 | caravelas
# Processing Record 22 of Set 5 | murray bridge
# Processing Record 23 of Set 5 | gouyave
# Processing Record 24 of Set 5 | bermejo
# Processing Record 25 of Set 5 | along
# Processing Record 26 of Set 5 | saint-pierre
# Processing Record 27 of Set 5 | arman
# Processing Record 28 of Set 5 | nuevo progreso
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | coihaique
# Processing Record 31 of Set 5 | ust-kuyga
# Processing Record 32 of Set 5 | kharabali
# Processing Record 33 of Set 5 | karpathos
# Processing Record 34 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 5 | birao
# Processing Record 36 of Set 5 | faya
# Processing Record 37 of Set 5 | banda aceh
# Processing Record 38 of Set 5 | jasper
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | arys
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | aksu
# Processing Record 43 of Set 5 | ferkessedougou
# Processing Record 44 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 5 | tam ky
# Processing Record 46 of Set 5 | fonte boa
# Processing Record 47 of Set 5 | saint-francois
# Processing Record 48 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 5 | villazon
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | azua
# Processing Record 2 of Set 6 | port moresby
# Processing Record 3 of Set 6 | la rioja
# Processing Record 4 of Set 6 | ishigaki
# Processing Record 5 of Set 6 | dwarka
# Processing Record 6 of Set 6 | piopio
# Processing Record 7 of Set 6 | muyezerskiy
# Processing Record 8 of Set 6 | dukat
# Processing Record 9 of Set 6 | foam lake
# Processing Record 10 of Set 6 | meadow lake
# Processing Record 11 of Set 6 | yakeshi
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | magadan
# Processing Record 14 of Set 6 | cidreira
# Processing Record 15 of Set 6 | siverskiy
# Processing Record 16 of Set 6 | rio tercero
# Processing Record 17 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 18 of Set 6 | peabiru
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | parnamirim
# Processing Record 21 of Set 6 | portel
# Processing Record 22 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 6 | deputatskiy
# Processing Record 24 of Set 6 | cascais
# Processing Record 25 of Set 6 | dongsheng
# Processing Record 26 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 6 | hambantota
# Processing Record 28 of Set 6 | ko samui
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | zhanaozen
# Processing Record 31 of Set 6 | paraibano
# Processing Record 32 of Set 6 | gao
# Processing Record 33 of Set 6 | carutapera
# Processing Record 34 of Set 6 | luyang
# Processing Record 35 of Set 6 | luderitz
# Processing Record 36 of Set 6 | newport
# Processing Record 37 of Set 6 | hovd
# Processing Record 38 of Set 6 | opunake
# Processing Record 39 of Set 6 | astara
# Processing Record 40 of Set 6 | richards bay
# Processing Record 41 of Set 6 | tubmanburg
# Processing Record 42 of Set 6 | constantine
# Processing Record 43 of Set 6 | fare
# Processing Record 44 of Set 6 | loikaw
# Processing Record 45 of Set 6 | chern
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | stillwater
# Processing Record 48 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 6 | matagami
# Processing Record 50 of Set 6 | sioux lookout
# Processing Record 1 of Set 7 | ust-tsilma
# Processing Record 2 of Set 7 | thyboron
# Processing Record 3 of Set 7 | vila franca do campo
# Processing Record 4 of Set 7 | sonthofen
# Processing Record 5 of Set 7 | batamshinskiy
# Processing Record 6 of Set 7 | sibolga
# Processing Record 7 of Set 7 | nuuk
# Processing Record 8 of Set 7 | thompson
# Processing Record 9 of Set 7 | kedrovyy
# Processing Record 10 of Set 7 | peniche
# Processing Record 11 of Set 7 | aleksandrov gay
# Processing Record 12 of Set 7 | rawson
# Processing Record 13 of Set 7 | necochea
# Processing Record 14 of Set 7 | mitsamiouli
# Processing Record 15 of Set 7 | qasigiannguit
# Processing Record 16 of Set 7 | dentsville
# Processing Record 17 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 7 | garowe
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | araouane
# Processing Record 21 of Set 7 | metro
# Processing Record 22 of Set 7 | thinadhoo
# Processing Record 23 of Set 7 | filadelfia
# Processing Record 24 of Set 7 | oxford
# Processing Record 25 of Set 7 | muros
# Processing Record 26 of Set 7 | tarauaca
# Processing Record 27 of Set 7 | kidal
# Processing Record 28 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | bitung
# Processing Record 31 of Set 7 | talnakh
# Processing Record 32 of Set 7 | vostok
# Processing Record 33 of Set 7 | aklavik
# Processing Record 34 of Set 7 | bundaberg
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | mindelo
# Processing Record 37 of Set 7 | aquiraz
# Processing Record 38 of Set 7 | shimoda
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | papara
# Processing Record 41 of Set 7 | sao jose da coroa grande
# Processing Record 42 of Set 7 | leona vicario
# Processing Record 43 of Set 7 | kharp
# Processing Record 44 of Set 7 | miri
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | port-cartier
# Processing Record 47 of Set 7 | ancud
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | bonavista
# Processing Record 50 of Set 7 | podosinovets
# Processing Record 1 of Set 8 | los alamos
# Processing Record 2 of Set 8 | kudahuvadhoo
# Processing Record 3 of Set 8 | iqaluit
# Processing Record 4 of Set 8 | teguldet
# Processing Record 5 of Set 8 | robertsport
# Processing Record 6 of Set 8 | timra
# Processing Record 7 of Set 8 | belmonte
# Processing Record 8 of Set 8 | kumluca
# Processing Record 9 of Set 8 | angoche
# Processing Record 10 of Set 8 | srednekolymsk
# Processing Record 11 of Set 8 | rulenge
# Processing Record 12 of Set 8 | trojes
# Processing Record 13 of Set 8 | nome
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | norrtalje
# Processing Record 16 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 8 | nyurba
# Processing Record 18 of Set 8 | filimonovo
# Processing Record 19 of Set 8 | isangel
# Processing Record 20 of Set 8 | fuxin
# Processing Record 21 of Set 8 | rocha
# Processing Record 22 of Set 8 | songjianghe
# Processing Record 23 of Set 8 | egvekinot
# Processing Record 24 of Set 8 | sao sebastiao
# Processing Record 25 of Set 8 | marawi
# Processing Record 26 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 8 | valdivia
# Processing Record 28 of Set 8 | conde
# Processing Record 29 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 30 of Set 8 | pangody
# Processing Record 31 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 8 | general pico
# Processing Record 33 of Set 8 | navsari
# Processing Record 34 of Set 8 | buala
# Processing Record 35 of Set 8 | weston
# Processing Record 36 of Set 8 | belen
# Processing Record 37 of Set 8 | snezhnogorsk
# Processing Record 38 of Set 8 | san cristobal
# Processing Record 39 of Set 8 | phonhong
# Processing Record 40 of Set 8 | berasia
# Processing Record 41 of Set 8 | flin flon
# Processing Record 42 of Set 8 | tessalit
# Processing Record 43 of Set 8 | laguna
# Processing Record 44 of Set 8 | sale
# Processing Record 45 of Set 8 | coquimbo
# Processing Record 46 of Set 8 | bam
# Processing Record 47 of Set 8 | galesong
# Processing Record 48 of Set 8 | mopti
# Processing Record 49 of Set 8 | gayny
# Processing Record 50 of Set 8 | talcahuano
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | siloam springs
# Processing Record 3 of Set 9 | haines junction
# Processing Record 4 of Set 9 | murfreesboro
# Processing Record 5 of Set 9 | ponta delgada
# Processing Record 6 of Set 9 | dangara
# Processing Record 7 of Set 9 | seymchan
# Processing Record 8 of Set 9 | nizhniy odes
# Processing Record 9 of Set 9 | prince rupert
# Processing Record 10 of Set 9 | mathbaria
# Processing Record 11 of Set 9 | lasa
# Processing Record 12 of Set 9 | winneba
# Processing Record 13 of Set 9 | ulaangom
# Processing Record 14 of Set 9 | kaeo
# Processing Record 15 of Set 9 | bealanana
# Processing Record 16 of Set 9 | skibby
# Processing Record 17 of Set 9 | gat
# Processing Record 18 of Set 9 | simpang
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | polunochnoye
# Processing Record 21 of Set 9 | bilma
# Processing Record 22 of Set 9 | paamiut
# Processing Record 23 of Set 9 | ankazobe
# Processing Record 24 of Set 9 | longyearbyen
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | moranbah
# Processing Record 27 of Set 9 | atherton
# Processing Record 28 of Set 9 | evensk
# Processing Record 29 of Set 9 | floro
# Processing Record 30 of Set 9 | gander
# Processing Record 31 of Set 9 | sobolevo
# Processing Record 32 of Set 9 | kampong chhnang
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | boende
# Processing Record 36 of Set 9 | cabedelo
# Processing Record 37 of Set 9 | myslenice
# Processing Record 38 of Set 9 | san felipe
# Processing Record 39 of Set 9 | rockport
# Processing Record 40 of Set 9 | mutis
# Processing Record 41 of Set 9 | cockburn town
# Processing Record 42 of Set 9 | iskateley
# Processing Record 43 of Set 9 | baykit
# Processing Record 44 of Set 9 | la ronge
# Processing Record 45 of Set 9 | ugoofaaru
# Processing Record 46 of Set 9 | juba
# Processing Record 47 of Set 9 | awjilah
# Processing Record 48 of Set 9 | andenes
# Processing Record 49 of Set 9 | tilichiki
# Processing Record 50 of Set 9 | christiana
# Processing Record 1 of Set 10 | buin
# Processing Record 2 of Set 10 | urdoma
# Processing Record 3 of Set 10 | vila do maio
# Processing Record 4 of Set 10 | buriti dos lopes
# Processing Record 5 of Set 10 | griffith
# Processing Record 6 of Set 10 | bustamante
# Processing Record 7 of Set 10 | sechura
# Processing Record 8 of Set 10 | borujan
# City not found. Skipping...
# Processing Record 9 of Set 10 | gravelbourg
# Processing Record 10 of Set 10 | abapo
# Processing Record 11 of Set 10 | mazagao
# Processing Record 12 of Set 10 | namibe
# Processing Record 13 of Set 10 | aktas
# Processing Record 14 of Set 10 | jiaonan
# Processing Record 15 of Set 10 | severo-yeniseyskiy
# Processing Record 16 of Set 10 | ozinki
# Processing Record 17 of Set 10 | sulangan
# Processing Record 18 of Set 10 | vilyuysk
# Processing Record 19 of Set 10 | airai
# Processing Record 20 of Set 10 | sorong
# Processing Record 21 of Set 10 | belle fourche
# Processing Record 22 of Set 10 | eregli
# Processing Record 23 of Set 10 | limoges
# Processing Record 24 of Set 10 | gravdal
# Processing Record 25 of Set 10 | sakakah
# Processing Record 26 of Set 10 | englewood
# Processing Record 27 of Set 10 | caconda
# Processing Record 28 of Set 10 | bredy
# Processing Record 29 of Set 10 | khorixas
# Processing Record 30 of Set 10 | arroyo
# Processing Record 31 of Set 10 | burgeo
# Processing Record 32 of Set 10 | rincon
# Processing Record 33 of Set 10 | udomlya
# Processing Record 34 of Set 10 | amarpur
# Processing Record 35 of Set 10 | zacamulpa
# Processing Record 36 of Set 10 | sangar
# Processing Record 37 of Set 10 | jardim
# Processing Record 38 of Set 10 | cabo san lucas
# Processing Record 39 of Set 10 | dondo
# Processing Record 40 of Set 10 | konongo
# Processing Record 41 of Set 10 | nangong
# Processing Record 42 of Set 10 | nizhniy kuranakh
# Processing Record 43 of Set 10 | fukue
# Processing Record 44 of Set 10 | bishop auckland
# Processing Record 45 of Set 10 | narsaq
# Processing Record 46 of Set 10 | panaba
# Processing Record 47 of Set 10 | sao felix do xingu
# Processing Record 48 of Set 10 | viedma
# Processing Record 49 of Set 10 | khilok
# Processing Record 50 of Set 10 | aryiropoulion
# Processing Record 1 of Set 11 | muzhi
# Processing Record 2 of Set 11 | ahipara
# Processing Record 3 of Set 11 | teahupoo
# Processing Record 4 of Set 11 | acajutla
# Processing Record 5 of Set 11 | kushima
# Processing Record 6 of Set 11 | atagay
# Processing Record 7 of Set 11 | amapa
# Processing Record 8 of Set 11 | uarini
# Processing Record 9 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 11 | mana
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | canutama
# Processing Record 13 of Set 11 | faanui
# Processing Record 14 of Set 11 | koungou
# Processing Record 15 of Set 11 | teberda
# Processing Record 16 of Set 11 | atar
# Processing Record 17 of Set 11 | leme
# Processing Record 18 of Set 11 | gaspe
# Processing Record 19 of Set 11 | sines
# Processing Record 20 of Set 11 | marzuq
# Processing Record 21 of Set 11 | usinsk
# Processing Record 22 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 11 | kulob
# Processing Record 24 of Set 11 | oyama
# Processing Record 25 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 26 of Set 11 | itarema
# Processing Record 27 of Set 11 | inhambane
# Processing Record 28 of Set 11 | flinders
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | chongoyape
# Processing Record 31 of Set 11 | lano
# Processing Record 32 of Set 11 | mogapi
# Processing Record 33 of Set 11 | grand-santi
# Processing Record 34 of Set 11 | amuntai
# Processing Record 35 of Set 11 | asau
# Processing Record 36 of Set 11 | mount pleasant
# Processing Record 37 of Set 11 | mutare
# Processing Record 38 of Set 11 | menongue
# Processing Record 39 of Set 11 | presidencia roque saenz pena
# Processing Record 40 of Set 11 | robinson
# Processing Record 41 of Set 11 | mingyue
# Processing Record 42 of Set 11 | quang ngai
# Processing Record 43 of Set 11 | malia
# Processing Record 44 of Set 11 | conceicao do araguaia
# Processing Record 45 of Set 11 | bonthe
# Processing Record 46 of Set 11 | novo cruzeiro
# Processing Record 47 of Set 11 | manyana
# Processing Record 48 of Set 11 | puerto del rosario
# Processing Record 49 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 11 | wai
# Processing Record 1 of Set 12 | altay
# Processing Record 2 of Set 12 | ayan
# Processing Record 3 of Set 12 | itupiranga
# Processing Record 4 of Set 12 | nyuksenitsa
# Processing Record 5 of Set 12 | camara de lobos
# Processing Record 6 of Set 12 | puerto leguizamo
# Processing Record 7 of Set 12 | goderich
# Processing Record 8 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 12 | queenstown
# Processing Record 10 of Set 12 | toledo
# Processing Record 11 of Set 12 | bosaso
# Processing Record 12 of Set 12 | high prairie
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | beaverlodge
# Processing Record 15 of Set 12 | amazar
# Processing Record 16 of Set 12 | baracoa
# Processing Record 17 of Set 12 | rongcheng
# Processing Record 18 of Set 12 | westport
# Processing Record 19 of Set 12 | narkevychi
# Processing Record 20 of Set 12 | raga
# Processing Record 21 of Set 12 | acarau
# Processing Record 22 of Set 12 | buy
# Processing Record 23 of Set 12 | antofagasta
# Processing Record 24 of Set 12 | killybegs
# Processing Record 25 of Set 12 | othonoi
# City not found. Skipping...
# Processing Record 26 of Set 12 | yate
# Processing Record 27 of Set 12 | houma
# Processing Record 28 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 12 | saint george
# Processing Record 30 of Set 12 | sozopol
# Processing Record 31 of Set 12 | moussoro
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | eureka
# Processing Record 34 of Set 12 | port hedland
# Processing Record 35 of Set 12 | chalus
# Processing Record 36 of Set 12 | wilmington
# Processing Record 37 of Set 12 | vestmanna
# Processing Record 38 of Set 12 | harlingen
# Processing Record 39 of Set 12 | kaduqli
# Processing Record 40 of Set 12 | port augusta
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | nouakchott
# Processing Record 43 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 12 | alta floresta
# Processing Record 45 of Set 12 | nantucket
# Processing Record 46 of Set 12 | kita
# Processing Record 47 of Set 12 | coulommiers
# Processing Record 48 of Set 12 | ngunguru
# Processing Record 49 of Set 12 | los llanos de aridane
# Processing Record 50 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 2 of Set 13 | kibungo
# Processing Record 3 of Set 13 | vysokogornyy
# Processing Record 4 of Set 13 | sisimiut
# Processing Record 5 of Set 13 | umea
# Processing Record 6 of Set 13 | svetlogorsk
# Processing Record 7 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 13 | domoni
# Processing Record 9 of Set 13 | clarence town
# Processing Record 10 of Set 13 | tromso
# Processing Record 11 of Set 13 | singaraja
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Palmer      US  42.1584  -72.3287     21.76        42           0
# 1       Aloleng      PH  16.1307  119.7824     76.53        78           3
# 2       Lithgow      AU -33.4833  150.1500     55.71        91          64
# 3     Fresnillo      MX  23.1667 -102.8833     56.75        35          95
# 4  Krasnoselkup      RU  65.7000   82.4667      2.70        98          76
# 5       Rikitea      PF -23.1203 -134.9692     78.44        74         100
# 6          Hilo      US  19.7297 -155.0900     78.80        72           0
# 7        Albany      US  42.6001  -73.9662     17.58        48           6
# 8     Jamestown      US  42.0970  -79.2353     20.52        29           0
# 9     Grindavik      IS  63.8424  -22.4338     41.47        87          75
#
#    Wind Speed           Current Description
# 0        5.75                     clear sky
# 1        5.99                     clear sky
# 2        6.49                 broken clouds
# 3       17.85               overcast clouds
# 4       10.45                 broken clouds
# 5        8.84               overcast clouds
# 6        8.05                     clear sky
# 7        5.70                     clear sky
# 8        5.75                     clear sky
# 9       44.87  light intensity drizzle rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
